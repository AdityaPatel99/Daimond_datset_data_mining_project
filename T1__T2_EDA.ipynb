# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data  = pd.read_csv('diamonds.csv')
data
# Out:
#         Unnamed: 0       cut    color clarity  carat_weight cut_quality  lab  \
# 0                0     Round        E    VVS2          0.09   Excellent  IGI
# 1                1     Round        E    VVS2          0.09   Very Good  IGI
# 2                2     Round        E    VVS2          0.09   Excellent  IGI
# 3                3     Round        E    VVS2          0.09   Excellent  IGI
# 4                4     Round        E    VVS2          0.09   Very Good  IGI
# ...            ...       ...      ...     ...           ...         ...  ...
# 219698      219699     Round        E     VS1         10.65   Excellent  GIA
# 219699      219700   Radiant  unknown     VS2          5.17     unknown  GIA
# 219700      219701     Round        E     VS1         18.07   Excellent  GIA
# 219701      219702  Princess  unknown     SI2          0.90     unknown  GIA
# 219702      219703      Pear  unknown    VVS2         10.03     unknown  GIA
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219703 entries, 0 to 219702
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   219703 non-null  int64
#  1   cut                          219703 non-null  object
#  2   color                        219703 non-null  object
#  3   clarity                      219703 non-null  object
#  4   carat_weight                 219703 non-null  float64
#  5   cut_quality                  219703 non-null  object
#  6   lab                          219703 non-null  object
#  7   symmetry                     219703 non-null  object
#  8   polish                       219703 non-null  object
#  9   eye_clean                    219703 non-null  object
#  10  culet_size                   219703 non-null  object
#  11  culet_condition              219703 non-null  object
# ...

# %% [markdown]
# ##**COLUMN ANALYSIS:**

# %% [markdown]
# ## 1. Cut

# %% [markdown]
# Cut refers to one of the 10 or so most common diamond cuts. This dataset has an additional one called the 'Cushion Modified'.

# %% [markdown]
# Different types of cuts are shown below in the image.

# %%
sb.countplot(x=data["cut"])
count = data["cut"].value_counts()
count
# Out:
# Round               158316
# Oval                 13857
# Emerald              11091
# Pear                  9860
# Princess              7050
# Radiant               5630
# Heart                 4774
# Cushion Modified      3984
# Marquise              2916
# Asscher               1696
# Cushion                529
# Name: cut, dtype: int64

# %% [markdown]
# ### Observation:
# Datatype - str
# Attribute type - Categorical
# There are no unknown values present.

# %% [markdown]
# ## 2. Color

# %% [markdown]
# Clear diamonds are graded D-Z. The higher letters more yellowish but are often better values since color is hard to determine once in a ring.

# %%
sb.countplot(x=data["color"])
count = data["color"].value_counts()
count
# Out:
# E          33103
# F          31566
# D          30873
# G          29184
# H          26073
# I          22364
# J          16898
# K          11750
# unknown     9162
# L           5683
# M           3047
# Name: color, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *   Attribute type - Categorical
# *   Unknown values are about 4.17% of the total data for this column.

# %% [markdown]
# ## Clarity

# %% [markdown]
# clarity refers the inclusions (i.e., internal flaws) in the diamonds seen though a jewelers loupe or microscope. Fewer and smaller are better.

# %% [markdown]
# Below shown image represents all the clarity levels for the diamonds in its hierachy

# %%
sb.countplot(x=data["clarity"])
count = data["clarity"].value_counts()
count
# Out:
# SI1     38627
# VS2     38173
# VS1     36956
# SI2     31105
# VVS2    28985
# VVS1    27877
# IF       9974
# I1       6961
# I2        944
# I3         91
# SI3        10
# Name: clarity, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are about 4.17% of the total data for this column.

# %% [markdown]
# ## Carat Weight

# %% [markdown]
# carat_weight Refers to the mass of the diamond. It's loosely connected with dimension of a diamond but cut and cut_quality tends to play an equally large if not larger role.

# %%
sb.countplot(x=data["carat_weight"])
count = data["carat_weight"].value_counts()
count
# Out:
# 0.30     33075
# 0.50     18242
# 0.40     10998
# 0.31      8897
# 1.00      8209
#          ...
# 7.75         1
# 8.41         1
# 10.79        1
# 6.69         1
# 18.07        1
# Name: carat_weight, Length: 878, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   There are no unknown values in this column.

# %% [markdown]
# ## Cut Quality

# %% [markdown]
# cut_quality refers the GIA Cut Grading System which was developed in 2005 and is de facto standard.

# %%
sb.countplot(x=data["cut_quality"])
count = data["cut_quality"].value_counts()
count
# Out:
# Excellent    124861
# unknown       60607
# Very Good     34201
# Good             28
# Fair              5
# Ideal             1
# Name: cut_quality, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are about 27.58% of the total data for this column.

# %% [markdown]
# ## Lab

# %% [markdown]
# lab is the grading lab. The big three are GIA, IGI and HRD. Each diamond gets a lab certificate that looks like this.

# %%
sb.countplot(x=data["lab"])
count = data["lab"].value_counts()
count
# Out:
# GIA    200434
# IGI     15865
# HRD      3404
# Name: lab, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Symmetry

# %% [markdown]
# Symmertricity in diamond

# %%
sb.countplot(x=data["symmetry"])
count = data["symmetry"].value_counts()
count
# Out:
# Excellent    131619
# Very Good     83143
# Good           4609
# Fair            325
# Poor              7
# Name: symmetry, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   There are no unknown values in this column.

# %% [markdown]
# ## Polish

# %% [markdown]
# Polish quality of diamond

# %%
sb.countplot(x=data["polish"])
count = data["polish"].value_counts()
count
# Out:
# Excellent    175806
# Very Good     42323
# Good           1565
# Fair              7
# Poor              2
# Name: polish, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   There are no unknown values in this column.

# %% [markdown]
# ## Eye Clean

# %% [markdown]
# eye-clean refers to the blemishes or inclusions can see with a the naked eye. There are 10 grades.

# %%
sb.countplot(x=data["eye_clean"])
count = data["eye_clean"].value_counts()
count
# Out:
# unknown       156916
# Yes            61931
# Borderline       515
# E1               300
# No                41
# Name: eye_clean, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 71.42% of the total data for this column.

# %% [markdown]
# ## Culet Size

# %% [markdown]
# culet_size is the size of the circle you'd see if you looked straight down. None is ideal because it affects the amount of light that gets reflected.

# %%
sb.countplot(x=data["culet_size"])
count = data["culet_size"].value_counts()
count
# Out:
# N          131899
# unknown     85740
# VS           1345
# S             476
# M             163
# L              58
# SL             14
# EL              4
# VL              4
# Name: culet_size, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are about 39.02% of the total data for this column.

# %% [markdown]
# ## Culet Condition

# %% [markdown]
# culet_condition indicates if the culet has any chipping, which is why some diamonds don't close to a point but rather a very small flat spot.

# %%
sb.countplot(x=data["culet_condition"])
count = data["culet_condition"].value_counts()
count
# Out:
# unknown    204384
# Pointed     15293
# Chipped        18
# Abraded         8
# Name: culet_condition, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 93.02% of the total data for this column.

# %% [markdown]
# ## Depth Percent

# %% [markdown]
# depth_percent and table_percent are the relative measurements of the flat part of the top and the depth. This varies somewhat by cut.

# %%
sb.countplot(x=data["depth_percent"])
count = data["depth_percent"].value_counts()
count
# Out:
# 62.6    7992
# 62.7    7921
# 62.5    7765
# 62.4    7309
# 62.8    7240
#         ...
# 86.8       1
# 25.9       1
# 42.7       1
# 42.4       1
# 37.6       1
# Name: depth_percent, Length: 534, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - float
# *  Attribute type - Numerical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Table Percent

# %%
sb.countplot(x=data["table_percent"])
count = data["table_percent"].value_counts()
count
# Out:
# 57.0    37918
# 58.0    32384
# 56.0    30295
# 59.0    25638
# 60.0    19396
#         ...
# 66.6        1
# 55.9        1
# 70.9        1
# 64.3        1
# 13.5        1
# Name: table_percent, Length: 235, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - float
# *  Attribute type - Numerical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Meas Length

# %% [markdown]
# meas_length, meas_width, meas_depth are the absolute measurements of stone.

# %%
sb.countplot(x=data["meas_length"])
count = data["meas_length"].value_counts()
count
# Out:
# 4.27     2971
# 4.26     2888
# 4.28     2860
# 4.25     2752
# 4.29     2681
#          ...
# 2.95        1
# 2.79        1
# 16.24       1
# 15.69       1
# 17.06       1
# Name: meas_length, Length: 1415, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - float
# *  Attribute type - Numerical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Meas Width

# %%
sb.countplot(x=data["meas_width"])
count = data["meas_width"].value_counts()
count
# Out:
# 4.29     3608
# 4.30     3454
# 4.28     3369
# 4.31     2974
# 4.32     2835
#          ...
# 13.29       1
# 13.34       1
# 15.32       1
# 14.39       1
# 17.10       1
# Name: meas_width, Length: 1155, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - float
# *  Attribute type - Numerical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Meas Depth

# %%
sb.countplot(x=data["meas_depth"])
count = data["meas_depth"].value_counts()
count
# Out:
# 2.68     5970
# 2.69     5500
# 2.67     5057
# 2.70     3960
# 2.66     3941
#          ...
# 68.10       1
# 58.60       1
# 43.30       1
# 9.90        1
# 10.20       1
# Name: meas_depth, Length: 852, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - float
# *  Attribute type - Numerical
# *   There are no unknown values in this column.

# %% [markdown]
# ## Girdle Min

# %% [markdown]
# girdle min/max are where the id of a stone is engraved they also are where the meets the setting and play a role in reflection. There are 9 values ranging from extremely thin to extremely thick

# %%
sb.countplot(x=data["girdle_min"])
count = data["girdle_min"].value_counts()
count
# Out:
# unknown    83432
# M          74421
# STK        26335
# TN         16744
# TK         10353
# VTK         4471
# XTK         1981
# VTN         1650
# XTN          292
# STN           24
# Name: girdle_min, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are about 37.97% of the total data for this column.

# %% [markdown]
# ## Girdle Max

# %%
sb.countplot(x=data["girdle_max"])
count = data["girdle_max"].value_counts()
count
# Out:
# unknown    84295
# STK        70440
# TK         25186
# M          17977
# VTK        12638
# XTK         7647
# TN          1363
# VTN          111
# XTN           34
# STN           12
# Name: girdle_max, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are about 38.36% of the total data for this column.

# %% [markdown]
# ## Fluor Color

# %% [markdown]
# fluor columns refer to the effect of long wave UV light. According to GIA 25-35% have it; for ~10% of those it's noticeable to an expert.

# %% [markdown]
# fancy columns refer to colored diamonds. They can be natural like the extremely rare blue diamonds, or lab grown. The columns refer to the colors, secondary colors and their intensity.

# %%
sb.countplot(x=data["fluor_color"])
count = data["fluor_color"].value_counts()
count
# Out:
# unknown    203977
# Blue        15219
# Yellow        400
# Green          55
# White          42
# Orange         10
# Name: fluor_color, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 92.84% of the total data for this column.

# %% [markdown]
# ## Fluor Intensity

# %%
sb.countplot(x=data["fluor_intensity"])
count = data["fluor_intensity"].value_counts()
count
# Out:
# None           143491
# Faint           38302
# Medium          20705
# Strong          13243
# Very Slight      2729
# Very Strong      1093
# unknown           128
# Slight             12
# Name: fluor_intensity, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Ordinal
# *   Unknown values are less than 1% of the total data for this column.

# %% [markdown]
# ## Fancy Color Dominant Color

# %% [markdown]
# fancy_color_ columns have to do with colored diamonds. Formerly, extremely rare but now common, popular, and almost always lab grown

# %%
sb.countplot(x=data["fancy_color_dominant_color"])
count = data["fancy_color_dominant_color"].value_counts()
count
# Out:
# unknown      210539
# Yellow         6487
# Pink           1369
# Brown           531
# Green           302
# Orange          271
# Purple           76
# Gray             66
# Blue             38
# Chameleon        12
# Black             6
# Red               4
# Other             2
# Name: fancy_color_dominant_color, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 95.82% of the total data for this column.

# %% [markdown]
# ## Fancy Color Secondary Color

# %%
sb.countplot(x=data["fancy_color_secondary_color"])
count = data["fancy_color_secondary_color"].value_counts()
count
# Out:
# unknown    218641
# Brown         306
# Yellow        239
# Orange        155
# Pink          126
# Green         105
# Purple         81
# Gray           36
# Blue           11
# Violet          2
# Red             1
# Name: fancy_color_secondary_color, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 99.51% of the total data for this column.

# %% [markdown]
# ## Fancy Color Overtone

# %%
sb.countplot(x=data["fancy_color_overtone"])
count = data["fancy_color_overtone"].value_counts()
count
# Out:
# unknown      217665
# None           1650
# Brownish        123
# Yellowish        78
# Orangey          54
# Pinkish          51
# Greenish         47
# Purplish         34
# Grayish           1
# Name: fancy_color_overtone, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 99.07% of the total data for this column.

# %% [markdown]
# ## Fancy Color Intensity

# %%
sb.countplot(x=data["fancy_color_intensity"])
count = data["fancy_color_intensity"].value_counts()
count
# Out:
# unknown          210541
# Fancy              3447
# Fancy Intense      1943
# Fancy Light        1288
# Fancy Deep          777
# Fancy Vivid         714
# Light               318
# Faint               238
# Fancy Dark          238
# Very Light          199
# Name: fancy_color_intensity, dtype: int64

# %% [markdown]
# ### Observation:
# *   Datatype - str
# *  Attribute type - Categorical
# *   Unknown values are about 95.82% of the total data for this column.

# %% [markdown]
# ## Total Sales Price

# %% [markdown]
# total_sales_price is priced in dollars.

# %%
sb.countplot(x=data["total_sales_price"])
count = data["total_sales_price"].value_counts()
count
# Out:
# 1008       675
# 990        583
# 924        576
# 972        540
# 900        528
#           ...
# 10064        1
# 26062        1
# 26070        1
# 26075        1
# 1449881      1
# Name: total_sales_price, Length: 22202, dtype: int64

# %% [markdown]
# # Other Plots for Observation:

# %%
sb.scatterplot(x=data["carat_weight"],y=data["total_sales_price"],hue=data["lab"])
# Out:
# <Axes: xlabel='carat_weight', ylabel='total_sales_price'>

# %% [markdown]
# Obsevation :--
#   This plot show the how carat_weight and Total_Sales_precie columns are correlated each other and also show the which lab has cirtified the diamond with respact to price and carat weight.

# %%
sb.catplot(data=data, x=data["cut"], y=data["total_sales_price"])

# %%
sb.catplot(data=data, x=data["clarity"], y=data["total_sales_price"])

# %%
sb.catplot(data=data, x=data["color"], y=data["total_sales_price"])

# %% [markdown]
# ### Observation :--
#
# This observation above three plots
#
# through this plot we can observe that most of the values in column cut type,clarity type and color are within a particular range.

# %% [markdown]
# # Problem Identification

# %% [markdown]
# From above EDA and Pattern we have identify the two main problems and decided to work both of them.Both the problem as listed as below.
#
# Problem 1. Predicting the sales price of diamonds from other given features.
#
# Problem 2: predicting the carat weight of diamonds from other given features.
