# %% [markdown]
# Course Project-1 (Data Preprocessing, EDA and Regression Analysis) Team Members:-
# 1. Aditya Patel 202311025
# 2. Keyur Dhanani 202311045
# 3. Dhyey Bhimani 202311004
# 4. Harshil Shah 202311053
# 5. Palak Bera 202311056
